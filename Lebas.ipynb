# %%
from keras.layers import Dense , Flatten
from keras.models import Sequential
import tensorflow as tf 

import matplotlib.pyplot as plt 
# %matplotlib widget

# %%
fashion = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = Sequential()

model.add(Flatten(input_shape = (28,28)))
model.add(Dense(128 , activation='relu'))
model.add(Dense(10))

model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , optimizer='adam' , metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(train_images,train_labels , epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4978 - accuracy: 0.8263
# Epoch 2/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3734 - accuracy: 0.8658
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3348 - accuracy: 0.8780
# Epoch 4/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3106 - accuracy: 0.8843
# Epoch 5/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2940 - accuracy: 0.8916
# Epoch 6/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2785 - accuracy: 0.8967
# Epoch 7/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2677 - accuracy: 0.9008
# Epoch 8/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2557 - accuracy: 0.9036
# Epoch 9/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2467 - accuracy: 0.9079
# Epoch 10/20
# ...

# %%
import cv2
import numpy as np 

img_set=cv2.imread('tshirt.png')
img_set=cv2.cvtColor(img_set, cv2.COLOR_BGR2GRAY)

img_change = np.array([img_set])
img_change=img_change/255

out= model.predict(img_change)

q=-1000
int=-1

for i in range(len(out[0])):
    if out[0][i]>q:
        q=out[0][i]
        int=i


print(class_names[int])
# Out:
# 1/1 [==============================] - 0s 18ms/step
# T-shirt

# %%
from keras_visualizer import visualizer

visualizer(model, file_name='picture',file_format='png')
